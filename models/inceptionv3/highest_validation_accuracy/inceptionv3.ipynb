# %%
# GPU details
# !nvidia-smi
# Out:
# Sun Dec 29 05:13:34 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.44       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    33W / 250W |  15765MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# CPU details
# !cat /proc/cpuinfo

# %%
# suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %%
import os # for basic operations like folder creation, directory validation etc
import glob # finds file according to wildcard given
import shutil # for moving files
import matplotlib.pyplot as plt # for plotting graphs and viewing images

# %%
'''
-> Generator class for applying image transformations
-> Can be used for image augmentation purposes if need be
-> Currently just normalises the image
-> tensorflow does not support importing and processing images
    so use this or use PIL(python image library)
'''

from keras.models import Model
from keras import backend as K
from keras.layers import Input
from keras.layers import Dense, GlobalAveragePooling2D, Dropout
from keras.applications.inception_v3 import InceptionV3
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import CSVLogger, ModelCheckpoint
from PIL import ImageFile

# ImageFile.LOAD_TRUNCATED_IMAGES = True

# Image dimension data
'''
    Sensor Type	    Image Size	            Set A	Set B	Resolution
DB1	Optical Sensor	640x480 (307 Kpixels)	100x8	10x8	500 dpi
DB2	Optical Sensor	328x364 (119 Kpixels)	100x8	10x8	500 dpi
DB3	Thermal sweeping
    Sensor	        300x480 (144 Kpixels)	100x8	10x8	512 dpi
DB4	SFinGe v3.0	    288x384 (108 Kpixels)	100x8	10x8	about 500 dpi
'''

img_width, img_height = 640, 480
train_data_dir = './drive/My Drive/dbs/DB1_B/dataset'
validation_data_dir = '../input/fingerprint-db/DB/DB_1/dataset'
nb_train_samples = 1200
nb_validation_samples = 300
batch_size = 16
epochs = 100

if K.image_data_format() == 'channels_last':
    input_tensor = Input(shape=(img_width, img_height, 3))
else:
    input_tensor = Input(shape=(3, img_width, img_height))


train_datagen = ImageDataGenerator(
    rescale=1./255,
#     horizontal_flip=True,
    rotation_range=30,
#     zoom_range=[0.1, 0.4],
    validation_split=0.40,
)

# test_datagen = ImageDataGenerator(
#     rescale=1./255,
#     horizontal_flip=True,
#     rotation_range=30,
#     zoom_range=[0.1, 0.4],
# )

train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='categorical',
        subset='training')

validation_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='categorical',
        subset='validation')

# imports the inceptionv3 pretained model
inception_model = InceptionV3(input_tensor=input_tensor, weights='imagenet', include_top=False)

x = inception_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(2048, activation='relu')(x)
# x = Dropout(0.20)(x)
# x = Dense(1024, activation='relu')(x)
# x = Dropout(0.20)(x)
# x = Dense(256, activation='relu')(x)
predictions = Dense(10, activation='softmax')(x)

model = Model(inputs=inception_model.input, outputs=predictions)

# freeze all convolutional InceptionV3 layers
# for layer in inception_model.layers:
#     layer.trainable = False

# functions to calculate f1score
def recall_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

def precision_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

def f1score(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy', f1score, recall_m, precision_m])
# model.summary()

filepath_accuracy = 'accuracy_weights.{epoch:02d}-{val_acc:.2f}.hdf5'
filepath_f1score = 'f1score_weights.{epoch:02d}-{val_f1score:.2f}.hdf5'

csv_logger = CSVLogger('training.log')

accuracy_checkpoint = ModelCheckpoint(filepath_accuracy, monitor='val_acc', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', period=1)
f1score_checkpoint = ModelCheckpoint(filepath_f1score, monitor='val_f1score', verbose=0, save_best_only=True, save_weights_only=True, mode='auto', period=1)

history = model.fit_generator(
        train_generator,
        steps_per_epoch=nb_train_samples // batch_size,
        epochs=epochs,
        shuffle=True,
        validation_data=validation_generator,
        validation_steps=nb_validation_samples // batch_size,
        callbacks=[csv_logger, accuracy_checkpoint, f1score_checkpoint]
        )
# Out:
# Found 50 images belonging to 10 classes.
# Found 30 images belonging to 10 classes.
# Epoch 1/100
# 75/75 [==============================] - 107s 1s/step - loss: 2.4520 - acc: 0.1275 - f1score: 0.0104 - recall_m: 0.0067 - precision_m: 0.0694 - val_loss: 8.8193 - val_acc: 0.1333 - val_f1score: 0.1070 - val_recall_m: 0.1000 - val_precision_m: 0.1156
# Epoch 2/100
# 75/75 [==============================] - 85s 1s/step - loss: 2.1432 - acc: 0.1526 - f1score: 0.0126 - recall_m: 0.0067 - precision_m: 0.1070 - val_loss: 13.4665 - val_acc: 0.1111 - val_f1score: 0.1019 - val_recall_m: 0.1000 - val_precision_m: 0.1039
# Epoch 3/100
# 75/75 [==============================] - 86s 1s/step - loss: 2.0333 - acc: 0.1703 - f1score: 0.0165 - recall_m: 0.0092 - precision_m: 0.0892 - val_loss: 8.9833 - val_acc: 0.1037 - val_f1score: 0.1347 - val_recall_m: 0.0926 - val_precision_m: 0.2526
# Epoch 4/100
# 75/75 [==============================] - 87s 1s/step - loss: 1.9968 - acc: 0.1857 - f1score: 0.0000e+00 - recall_m: 0.0000e+00 - precision_m: 0.0000e+00 - val_loss: 14.3827 - val_acc: 0.1000 - val_f1score: 0.1000 - val_recall_m: 0.1000 - val_precision_m: 0.1000
# Epoch 5/100
# 75/75 [==============================] - 83s 1s/step - loss: 1.9255 - acc: 0.1884 - f1score: 0.0174 - recall_m: 0.0100 - precision_m: 0.0714 - val_loss: 9.5102 - val_acc: 0.1037 - val_f1score: 0.1160 - val_recall_m: 0.1000 - val_precision_m: 0.1392
# Epoch 6/100
# 75/75 [==============================] - 87s 1s/step - loss: 2.0321 - acc: 0.1950 - f1score: 0.0195 - recall_m: 0.0109 - precision_m: 0.1048 - val_loss: 12.5761 - val_acc: 0.1000 - val_f1score: 0.1000 - val_recall_m: 0.1000 - val_precision_m: 0.1000
# Epoch 7/100
# 75/75 [==============================] - 86s 1s/step - loss: 1.9689 - acc: 0.1835 - f1score: 0.0078 - recall_m: 0.0042 - precision_m: 0.0602 - val_loss: 5.8558 - val_acc: 0.1185 - val_f1score: 0.0312 - val_recall_m: 0.0185 - val_precision_m: 0.1302
# Epoch 8/100
# 75/75 [==============================] - 86s 1s/step - loss: 1.8131 - acc: 0.2892 - f1score: 0.1000 - recall_m: 0.0586 - precision_m: 0.4071 - val_loss: 2.9211 - val_acc: 0.1593 - val_f1score: 0.1162 - val_recall_m: 0.0815 - val_precision_m: 0.2083
# Epoch 9/100
# 75/75 [==============================] - 84s 1s/step - loss: 1.6531 - acc: 0.3803 - f1score: 0.1810 - recall_m: 0.1120 - precision_m: 0.5476 - val_loss: 2.7668 - val_acc: 0.1889 - val_f1score: 0.1072 - val_recall_m: 0.0741 - val_precision_m: 0.2037
# Epoch 10/100
# 75/75 [==============================] - 86s 1s/step - loss: 1.5903 - acc: 0.3766 - f1score: 0.1807 - recall_m: 0.1136 - precision_m: 0.4929 - val_loss: 3.4372 - val_acc: 0.1370 - val_f1score: 0.0383 - val_recall_m: 0.0222 - val_precision_m: 0.1673
# Epoch 11/100
# 75/75 [==============================] - 86s 1s/step - loss: 1.3738 - acc: 0.4306 - f1score: 0.2815 - recall_m: 0.1964 - precision_m: 0.5577 - val_loss: 5.7646 - val_acc: 0.1111 - val_f1score: 0.0308 - val_recall_m: 0.0259 - val_precision_m: 0.0383
# Epoch 12/100
# 75/75 [==============================] - 86s 1s/step - loss: 1.2397 - acc: 0.4988 - f1score: 0.3674 - recall_m: 0.2787 - precision_m: 0.5736 - val_loss: 4.3302 - val_acc: 0.1519 - val_f1score: 0.1110 - val_recall_m: 0.0926 - val_precision_m: 0.1391
# Epoch 13/100
# 75/75 [==============================] - 84s 1s/step - loss: 1.3385 - acc: 0.4934 - f1score: 0.3607 - recall_m: 0.2782 - precision_m: 0.5559 - val_loss: 13.5713 - val_acc: 0.1111 - val_f1score: 0.1111 - val_recall_m: 0.1111 - val_precision_m: 0.1111
# Epoch 14/100
# 75/75 [==============================] - 86s 1s/step - loss: 1.2089 - acc: 0.5168 - f1score: 0.4443 - recall_m: 0.3583 - precision_m: 0.5977 - val_loss: 13.7024 - val_acc: 0.1259 - val_f1score: 0.1259 - val_recall_m: 0.1259 - val_precision_m: 0.1259
# Epoch 15/100
# 75/75 [==============================] - 86s 1s/step - loss: 1.1657 - acc: 0.5355 - f1score: 0.4379 - recall_m: 0.3519 - precision_m: 0.5955 - val_loss: 13.2597 - val_acc: 0.1148 - val_f1score: 0.1148 - val_recall_m: 0.1148 - val_precision_m: 0.1148
# Epoch 16/100
# 75/75 [==============================] - 86s 1s/step - loss: 1.1222 - acc: 0.5353 - f1score: 0.4644 - recall_m: 0.3794 - precision_m: 0.6230 - val_loss: 3.9928 - val_acc: 0.1778 - val_f1score: 0.1250 - val_recall_m: 0.1148 - val_precision_m: 0.1377
# Epoch 17/100
# 75/75 [==============================] - 83s 1s/step - loss: 1.0604 - acc: 0.6076 - f1score: 0.5473 - recall_m: 0.4693 - precision_m: 0.6689 - val_loss: 2.9462 - val_acc: 0.2815 - val_f1score: 0.2812 - val_recall_m: 0.2296 - val_precision_m: 0.3698
# Epoch 18/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.9864 - acc: 0.6309 - f1score: 0.5807 - recall_m: 0.5017 - precision_m: 0.7046 - val_loss: 2.9156 - val_acc: 0.3000 - val_f1score: 0.2981 - val_recall_m: 0.2481 - val_precision_m: 0.3749
# Epoch 19/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.9155 - acc: 0.6268 - f1score: 0.5788 - recall_m: 0.4991 - precision_m: 0.7105 - val_loss: 4.2428 - val_acc: 0.1444 - val_f1score: 0.1378 - val_recall_m: 0.1259 - val_precision_m: 0.1531
# Epoch 20/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.9795 - acc: 0.6070 - f1score: 0.5643 - recall_m: 0.4892 - precision_m: 0.6790 - val_loss: 10.6156 - val_acc: 0.2037 - val_f1score: 0.1699 - val_recall_m: 0.1630 - val_precision_m: 0.1780
# Epoch 21/100
# 75/75 [==============================] - 83s 1s/step - loss: 0.9411 - acc: 0.6545 - f1score: 0.6159 - recall_m: 0.5463 - precision_m: 0.7209 - val_loss: 3.9598 - val_acc: 0.2519 - val_f1score: 0.2689 - val_recall_m: 0.2481 - val_precision_m: 0.2949
# Epoch 22/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.7776 - acc: 0.6941 - f1score: 0.6603 - recall_m: 0.5951 - precision_m: 0.7561 - val_loss: 6.9423 - val_acc: 0.1481 - val_f1score: 0.1519 - val_recall_m: 0.1444 - val_precision_m: 0.1609
# Epoch 23/100
# 75/75 [==============================] - 87s 1s/step - loss: 1.0434 - acc: 0.5996 - f1score: 0.5548 - recall_m: 0.4787 - precision_m: 0.6719 - val_loss: 5.2659 - val_acc: 0.1333 - val_f1score: 0.1200 - val_recall_m: 0.1111 - val_precision_m: 0.1308
# Epoch 24/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.8678 - acc: 0.6752 - f1score: 0.6495 - recall_m: 0.5935 - precision_m: 0.7337 - val_loss: 7.4331 - val_acc: 0.1444 - val_f1score: 0.1310 - val_recall_m: 0.1296 - val_precision_m: 0.1324
# Epoch 25/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.6378 - acc: 0.7523 - f1score: 0.7253 - recall_m: 0.6706 - precision_m: 0.8020 - val_loss: 4.2165 - val_acc: 0.3259 - val_f1score: 0.3105 - val_recall_m: 0.2889 - val_precision_m: 0.3367
# Epoch 26/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.7813 - acc: 0.6949 - f1score: 0.6711 - recall_m: 0.6149 - precision_m: 0.7495 - val_loss: 5.9001 - val_acc: 0.1519 - val_f1score: 0.1538 - val_recall_m: 0.1444 - val_precision_m: 0.1651
# Epoch 27/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.5867 - acc: 0.7923 - f1score: 0.7698 - recall_m: 0.7164 - precision_m: 0.8472 - val_loss: 4.3811 - val_acc: 0.2407 - val_f1score: 0.2430 - val_recall_m: 0.2222 - val_precision_m: 0.2697
# Epoch 28/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.9648 - acc: 0.6492 - f1score: 0.6180 - recall_m: 0.5633 - precision_m: 0.6996 - val_loss: 4.1991 - val_acc: 0.2778 - val_f1score: 0.3041 - val_recall_m: 0.2741 - val_precision_m: 0.3430
# Epoch 29/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.5649 - acc: 0.7749 - f1score: 0.7586 - recall_m: 0.7067 - precision_m: 0.8339 - val_loss: 4.9097 - val_acc: 0.2259 - val_f1score: 0.1959 - val_recall_m: 0.1815 - val_precision_m: 0.2134
# Epoch 30/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.5663 - acc: 0.7956 - f1score: 0.7869 - recall_m: 0.7481 - precision_m: 0.8412 - val_loss: 3.4596 - val_acc: 0.2407 - val_f1score: 0.2025 - val_recall_m: 0.1815 - val_precision_m: 0.2308
# Epoch 31/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.6502 - acc: 0.7592 - f1score: 0.7289 - recall_m: 0.6944 - precision_m: 0.7779 - val_loss: 4.6484 - val_acc: 0.2037 - val_f1score: 0.1637 - val_recall_m: 0.1481 - val_precision_m: 0.1839
# Epoch 32/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.5220 - acc: 0.8051 - f1score: 0.7688 - recall_m: 0.7362 - precision_m: 0.8156 - val_loss: 4.2133 - val_acc: 0.2593 - val_f1score: 0.2597 - val_recall_m: 0.2370 - val_precision_m: 0.2878
# Epoch 33/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.4462 - acc: 0.8270 - f1score: 0.8294 - recall_m: 0.8111 - precision_m: 0.8559 - val_loss: 3.6790 - val_acc: 0.3259 - val_f1score: 0.2991 - val_recall_m: 0.2926 - val_precision_m: 0.3064
# Epoch 34/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.4885 - acc: 0.8199 - f1score: 0.7995 - recall_m: 0.7768 - precision_m: 0.8347 - val_loss: 13.3275 - val_acc: 0.1333 - val_f1score: 0.1333 - val_recall_m: 0.1333 - val_precision_m: 0.1333
# Epoch 35/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.4253 - acc: 0.8796 - f1score: 0.8610 - recall_m: 0.8390 - precision_m: 0.8916 - val_loss: 5.1680 - val_acc: 0.3407 - val_f1score: 0.3465 - val_recall_m: 0.3370 - val_precision_m: 0.3570
# Epoch 36/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.7074 - acc: 0.7644 - f1score: 0.7526 - recall_m: 0.7336 - precision_m: 0.7758 - val_loss: 12.9611 - val_acc: 0.1296 - val_f1score: 0.1297 - val_recall_m: 0.1296 - val_precision_m: 0.1299
# Epoch 37/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.6327 - acc: 0.7631 - f1score: 0.7351 - recall_m: 0.6872 - precision_m: 0.7990 - val_loss: 14.3945 - val_acc: 0.1000 - val_f1score: 0.1000 - val_recall_m: 0.1000 - val_precision_m: 0.1000
# Epoch 38/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.4518 - acc: 0.8131 - f1score: 0.7876 - recall_m: 0.7666 - precision_m: 0.8188 - val_loss: 13.2061 - val_acc: 0.1519 - val_f1score: 0.1519 - val_recall_m: 0.1519 - val_precision_m: 0.1519
# Epoch 39/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.3888 - acc: 0.8582 - f1score: 0.8517 - recall_m: 0.8384 - precision_m: 0.8742 - val_loss: 13.1593 - val_acc: 0.1407 - val_f1score: 0.1407 - val_recall_m: 0.1407 - val_precision_m: 0.1407
# Epoch 40/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.7129 - acc: 0.7667 - f1score: 0.7780 - recall_m: 0.7483 - precision_m: 0.8232 - val_loss: 4.0943 - val_acc: 0.2259 - val_f1score: 0.2176 - val_recall_m: 0.2074 - val_precision_m: 0.2297
# Epoch 41/100
# 75/75 [==============================] - 83s 1s/step - loss: 0.3453 - acc: 0.8824 - f1score: 0.8719 - recall_m: 0.8551 - precision_m: 0.9004 - val_loss: 3.6297 - val_acc: 0.3963 - val_f1score: 0.3993 - val_recall_m: 0.3926 - val_precision_m: 0.4069
# Epoch 42/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.2830 - acc: 0.9038 - f1score: 0.8900 - recall_m: 0.8798 - precision_m: 0.9071 - val_loss: 4.8812 - val_acc: 0.1852 - val_f1score: 0.1910 - val_recall_m: 0.1852 - val_precision_m: 0.1974
# Epoch 43/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.4753 - acc: 0.8393 - f1score: 0.8348 - recall_m: 0.8161 - precision_m: 0.8642 - val_loss: 6.5833 - val_acc: 0.1778 - val_f1score: 0.1815 - val_recall_m: 0.1778 - val_precision_m: 0.1857
# Epoch 44/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.2332 - acc: 0.9352 - f1score: 0.9370 - recall_m: 0.9219 - precision_m: 0.9615 - val_loss: 6.1443 - val_acc: 0.2037 - val_f1score: 0.1866 - val_recall_m: 0.1815 - val_precision_m: 0.1922
# Epoch 45/100
# 75/75 [==============================] - 83s 1s/step - loss: 0.3091 - acc: 0.9114 - f1score: 0.8976 - recall_m: 0.8916 - precision_m: 0.9081 - val_loss: 4.3918 - val_acc: 0.1296 - val_f1score: 0.1199 - val_recall_m: 0.1111 - val_precision_m: 0.1306
# Epoch 46/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.3087 - acc: 0.9044 - f1score: 0.8974 - recall_m: 0.8870 - precision_m: 0.9126 - val_loss: 14.4024 - val_acc: 0.1000 - val_f1score: 0.1000 - val_recall_m: 0.1000 - val_precision_m: 0.1000
# Epoch 47/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.2138 - acc: 0.9222 - f1score: 0.9132 - recall_m: 0.9073 - precision_m: 0.9237 - val_loss: 12.9814 - val_acc: 0.1704 - val_f1score: 0.1704 - val_recall_m: 0.1704 - val_precision_m: 0.1704
# Epoch 48/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.5774 - acc: 0.8216 - f1score: 0.8124 - recall_m: 0.7976 - precision_m: 0.8328 - val_loss: 5.4423 - val_acc: 0.3296 - val_f1score: 0.3293 - val_recall_m: 0.3185 - val_precision_m: 0.3412
# Epoch 49/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.4253 - acc: 0.8641 - f1score: 0.8598 - recall_m: 0.8458 - precision_m: 0.8815 - val_loss: 5.9945 - val_acc: 0.2296 - val_f1score: 0.2261 - val_recall_m: 0.2185 - val_precision_m: 0.2353
# Epoch 50/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.2170 - acc: 0.9319 - f1score: 0.9297 - recall_m: 0.9236 - precision_m: 0.9382 - val_loss: 4.4807 - val_acc: 0.3185 - val_f1score: 0.3141 - val_recall_m: 0.3074 - val_precision_m: 0.3221
# Epoch 51/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.3699 - acc: 0.8865 - f1score: 0.8793 - recall_m: 0.8683 - precision_m: 0.8973 - val_loss: 5.7928 - val_acc: 0.0926 - val_f1score: 0.0930 - val_recall_m: 0.0889 - val_precision_m: 0.0978
# Epoch 52/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.3182 - acc: 0.8683 - f1score: 0.8523 - recall_m: 0.8401 - precision_m: 0.8695 - val_loss: 4.2519 - val_acc: 0.1593 - val_f1score: 0.1587 - val_recall_m: 0.1519 - val_precision_m: 0.1663
# Epoch 53/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.4031 - acc: 0.8387 - f1score: 0.8387 - recall_m: 0.8230 - precision_m: 0.8678 - val_loss: 3.8800 - val_acc: 0.2704 - val_f1score: 0.2880 - val_recall_m: 0.2667 - val_precision_m: 0.3149
# Epoch 54/100
# 75/75 [==============================] - 88s 1s/step - loss: 0.2226 - acc: 0.9345 - f1score: 0.9224 - recall_m: 0.9163 - precision_m: 0.9310 - val_loss: 8.7535 - val_acc: 0.2296 - val_f1score: 0.2274 - val_recall_m: 0.2259 - val_precision_m: 0.2290
# Epoch 55/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1193 - acc: 0.9561 - f1score: 0.9490 - recall_m: 0.9420 - precision_m: 0.9626 - val_loss: 6.3715 - val_acc: 0.2481 - val_f1score: 0.2488 - val_recall_m: 0.2481 - val_precision_m: 0.2496
# Epoch 56/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.2006 - acc: 0.9471 - f1score: 0.9448 - recall_m: 0.9388 - precision_m: 0.9553 - val_loss: 5.4375 - val_acc: 0.3556 - val_f1score: 0.3534 - val_recall_m: 0.3444 - val_precision_m: 0.3634
# Epoch 57/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.2610 - acc: 0.9097 - f1score: 0.8973 - recall_m: 0.8915 - precision_m: 0.9055 - val_loss: 14.4603 - val_acc: 0.1000 - val_f1score: 0.1000 - val_recall_m: 0.1000 - val_precision_m: 0.1000
# Epoch 58/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.2968 - acc: 0.8908 - f1score: 0.8788 - recall_m: 0.8743 - precision_m: 0.8857 - val_loss: 6.6134 - val_acc: 0.1889 - val_f1score: 0.1822 - val_recall_m: 0.1778 - val_precision_m: 0.1871
# Epoch 59/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.2720 - acc: 0.9073 - f1score: 0.9151 - recall_m: 0.9073 - precision_m: 0.9295 - val_loss: 13.2509 - val_acc: 0.1185 - val_f1score: 0.1185 - val_recall_m: 0.1185 - val_precision_m: 0.1185
# Epoch 60/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1502 - acc: 0.9512 - f1score: 0.9490 - recall_m: 0.9446 - precision_m: 0.9578 - val_loss: 6.8064 - val_acc: 0.2296 - val_f1score: 0.2346 - val_recall_m: 0.2296 - val_precision_m: 0.2402
# Epoch 61/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.0833 - acc: 0.9727 - f1score: 0.9683 - recall_m: 0.9661 - precision_m: 0.9727 - val_loss: 4.8969 - val_acc: 0.2667 - val_f1score: 0.2367 - val_recall_m: 0.2259 - val_precision_m: 0.2492
# Epoch 62/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.1627 - acc: 0.9263 - f1score: 0.9315 - recall_m: 0.9255 - precision_m: 0.9419 - val_loss: 4.4592 - val_acc: 0.3593 - val_f1score: 0.3587 - val_recall_m: 0.3556 - val_precision_m: 0.3621
# Epoch 63/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.2652 - acc: 0.8966 - f1score: 0.8917 - recall_m: 0.8884 - precision_m: 0.8972 - val_loss: 6.5602 - val_acc: 0.2741 - val_f1score: 0.2788 - val_recall_m: 0.2741 - val_precision_m: 0.2840
# Epoch 64/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.5325 - acc: 0.7994 - f1score: 0.8008 - recall_m: 0.7952 - precision_m: 0.8071 - val_loss: 9.3250 - val_acc: 0.1593 - val_f1score: 0.1645 - val_recall_m: 0.1593 - val_precision_m: 0.1705
# Epoch 65/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.1843 - acc: 0.9534 - f1score: 0.9430 - recall_m: 0.9393 - precision_m: 0.9490 - val_loss: 14.3632 - val_acc: 0.1000 - val_f1score: 0.1000 - val_recall_m: 0.1000 - val_precision_m: 0.1000
# Epoch 66/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.2077 - acc: 0.9470 - f1score: 0.9499 - recall_m: 0.9461 - precision_m: 0.9561 - val_loss: 10.7593 - val_acc: 0.1704 - val_f1score: 0.1734 - val_recall_m: 0.1704 - val_precision_m: 0.1768
# Epoch 67/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.3004 - acc: 0.9228 - f1score: 0.9188 - recall_m: 0.9088 - precision_m: 0.9357 - val_loss: 5.6179 - val_acc: 0.2444 - val_f1score: 0.2394 - val_recall_m: 0.2370 - val_precision_m: 0.2419
# Epoch 68/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.2719 - acc: 0.8997 - f1score: 0.8896 - recall_m: 0.8857 - precision_m: 0.8960 - val_loss: 13.3379 - val_acc: 0.1185 - val_f1score: 0.1187 - val_recall_m: 0.1185 - val_precision_m: 0.1188
# Epoch 69/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.1967 - acc: 0.9437 - f1score: 0.9389 - recall_m: 0.9363 - precision_m: 0.9437 - val_loss: 13.7829 - val_acc: 0.1037 - val_f1score: 0.1037 - val_recall_m: 0.1037 - val_precision_m: 0.1037
# Epoch 70/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.2989 - acc: 0.9089 - f1score: 0.9100 - recall_m: 0.9064 - precision_m: 0.9160 - val_loss: 6.2303 - val_acc: 0.2444 - val_f1score: 0.2249 - val_recall_m: 0.2148 - val_precision_m: 0.2362
# Epoch 71/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.1255 - acc: 0.9594 - f1score: 0.9602 - recall_m: 0.9586 - precision_m: 0.9619 - val_loss: 4.5005 - val_acc: 0.2889 - val_f1score: 0.2971 - val_recall_m: 0.2852 - val_precision_m: 0.3113
# Epoch 72/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1222 - acc: 0.9653 - f1score: 0.9656 - recall_m: 0.9653 - precision_m: 0.9660 - val_loss: 5.5686 - val_acc: 0.2704 - val_f1score: 0.2744 - val_recall_m: 0.2667 - val_precision_m: 0.2833
# Epoch 73/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.0999 - acc: 0.9620 - f1score: 0.9646 - recall_m: 0.9620 - precision_m: 0.9694 - val_loss: 13.5906 - val_acc: 0.1259 - val_f1score: 0.1259 - val_recall_m: 0.1259 - val_precision_m: 0.1259
# Epoch 74/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.2830 - acc: 0.8975 - f1score: 0.9005 - recall_m: 0.8975 - precision_m: 0.9057 - val_loss: 13.6436 - val_acc: 0.1370 - val_f1score: 0.1370 - val_recall_m: 0.1370 - val_precision_m: 0.1370
# Epoch 75/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1339 - acc: 0.9593 - f1score: 0.9596 - recall_m: 0.9576 - precision_m: 0.9616 - val_loss: 6.5020 - val_acc: 0.2148 - val_f1score: 0.2174 - val_recall_m: 0.2148 - val_precision_m: 0.2201
# Epoch 76/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1041 - acc: 0.9637 - f1score: 0.9659 - recall_m: 0.9637 - precision_m: 0.9703 - val_loss: 7.2963 - val_acc: 0.2889 - val_f1score: 0.2948 - val_recall_m: 0.2889 - val_precision_m: 0.3013
# Epoch 77/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.0956 - acc: 0.9545 - f1score: 0.9619 - recall_m: 0.9545 - precision_m: 0.9759 - val_loss: 4.4469 - val_acc: 0.3000 - val_f1score: 0.2951 - val_recall_m: 0.2889 - val_precision_m: 0.3021
# Epoch 78/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.0637 - acc: 0.9860 - f1score: 0.9816 - recall_m: 0.9794 - precision_m: 0.9860 - val_loss: 5.8837 - val_acc: 0.2963 - val_f1score: 0.3028 - val_recall_m: 0.2926 - val_precision_m: 0.3144
# Epoch 79/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1189 - acc: 0.9669 - f1score: 0.9625 - recall_m: 0.9595 - precision_m: 0.9677 - val_loss: 13.7298 - val_acc: 0.1148 - val_f1score: 0.1148 - val_recall_m: 0.1148 - val_precision_m: 0.1148
# Epoch 80/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1079 - acc: 0.9554 - f1score: 0.9550 - recall_m: 0.9546 - precision_m: 0.9554 - val_loss: 9.2891 - val_acc: 0.1741 - val_f1score: 0.1748 - val_recall_m: 0.1741 - val_precision_m: 0.1756
# Epoch 81/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.1143 - acc: 0.9578 - f1score: 0.9578 - recall_m: 0.9578 - precision_m: 0.9578 - val_loss: 14.3850 - val_acc: 0.1000 - val_f1score: 0.1000 - val_recall_m: 0.1000 - val_precision_m: 0.1000
# Epoch 82/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.1683 - acc: 0.9454 - f1score: 0.9370 - recall_m: 0.9322 - precision_m: 0.9462 - val_loss: 6.0165 - val_acc: 0.3333 - val_f1score: 0.3213 - val_recall_m: 0.3111 - val_precision_m: 0.3331
# Epoch 83/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.1467 - acc: 0.9420 - f1score: 0.9494 - recall_m: 0.9420 - precision_m: 0.9635 - val_loss: 7.7390 - val_acc: 0.2667 - val_f1score: 0.2659 - val_recall_m: 0.2593 - val_precision_m: 0.2732
# Epoch 84/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1127 - acc: 0.9635 - f1score: 0.9447 - recall_m: 0.9404 - precision_m: 0.9515 - val_loss: 3.5826 - val_acc: 0.3259 - val_f1score: 0.3212 - val_recall_m: 0.3148 - val_precision_m: 0.3285
# Epoch 85/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.6903 - acc: 0.8076 - f1score: 0.7983 - recall_m: 0.7911 - precision_m: 0.8082 - val_loss: 7.6615 - val_acc: 0.2741 - val_f1score: 0.2753 - val_recall_m: 0.2704 - val_precision_m: 0.2807
# Epoch 86/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.2342 - acc: 0.9254 - f1score: 0.9225 - recall_m: 0.9180 - precision_m: 0.9293 - val_loss: 5.1319 - val_acc: 0.3926 - val_f1score: 0.3901 - val_recall_m: 0.3815 - val_precision_m: 0.3997
# Epoch 87/100
# 75/75 [==============================] - 86s 1s/step - loss: 0.2015 - acc: 0.9289 - f1score: 0.9271 - recall_m: 0.9215 - precision_m: 0.9372 - val_loss: 3.6485 - val_acc: 0.3963 - val_f1score: 0.3828 - val_recall_m: 0.3704 - val_precision_m: 0.3968
# Epoch 88/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1375 - acc: 0.9478 - f1score: 0.9504 - recall_m: 0.9478 - precision_m: 0.9552 - val_loss: 5.5066 - val_acc: 0.3519 - val_f1score: 0.3507 - val_recall_m: 0.3444 - val_precision_m: 0.3575
# Epoch 89/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.1041 - acc: 0.9677 - f1score: 0.9633 - recall_m: 0.9611 - precision_m: 0.9677 - val_loss: 5.2761 - val_acc: 0.3630 - val_f1score: 0.3627 - val_recall_m: 0.3593 - val_precision_m: 0.3665
# Epoch 90/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1682 - acc: 0.9469 - f1score: 0.9480 - recall_m: 0.9469 - precision_m: 0.9491 - val_loss: 3.3203 - val_acc: 0.4148 - val_f1score: 0.4156 - val_recall_m: 0.4074 - val_precision_m: 0.4247
# Epoch 91/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.0896 - acc: 0.9587 - f1score: 0.9587 - recall_m: 0.9521 - precision_m: 0.9719 - val_loss: 3.9458 - val_acc: 0.3741 - val_f1score: 0.3723 - val_recall_m: 0.3667 - val_precision_m: 0.3782
# Epoch 92/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.0975 - acc: 0.9596 - f1score: 0.9596 - recall_m: 0.9596 - precision_m: 0.9596 - val_loss: 4.7754 - val_acc: 0.3333 - val_f1score: 0.3324 - val_recall_m: 0.3185 - val_precision_m: 0.3492
# Epoch 93/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.1931 - acc: 0.9430 - f1score: 0.9403 - recall_m: 0.9355 - precision_m: 0.9496 - val_loss: 6.6899 - val_acc: 0.2704 - val_f1score: 0.2740 - val_recall_m: 0.2704 - val_precision_m: 0.2785
# Epoch 94/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.2044 - acc: 0.9280 - f1score: 0.9300 - recall_m: 0.9263 - precision_m: 0.9360 - val_loss: 5.6809 - val_acc: 0.3259 - val_f1score: 0.3297 - val_recall_m: 0.3185 - val_precision_m: 0.3426
# Epoch 95/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1429 - acc: 0.9505 - f1score: 0.9478 - recall_m: 0.9431 - precision_m: 0.9570 - val_loss: 4.2511 - val_acc: 0.3704 - val_f1score: 0.3746 - val_recall_m: 0.3667 - val_precision_m: 0.3833
# Epoch 96/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.0257 - acc: 0.9917 - f1score: 0.9917 - recall_m: 0.9909 - precision_m: 0.9926 - val_loss: 4.2897 - val_acc: 0.3741 - val_f1score: 0.3729 - val_recall_m: 0.3667 - val_precision_m: 0.3797
# Epoch 97/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.0958 - acc: 0.9554 - f1score: 0.9558 - recall_m: 0.9554 - precision_m: 0.9562 - val_loss: 6.8314 - val_acc: 0.2963 - val_f1score: 0.3045 - val_recall_m: 0.2963 - val_precision_m: 0.3137
# Epoch 98/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.2284 - acc: 0.9264 - f1score: 0.9290 - recall_m: 0.9256 - precision_m: 0.9347 - val_loss: 14.1094 - val_acc: 0.1074 - val_f1score: 0.1074 - val_recall_m: 0.1074 - val_precision_m: 0.1074
# Epoch 99/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1926 - acc: 0.9364 - f1score: 0.9309 - recall_m: 0.9273 - precision_m: 0.9369 - val_loss: 6.0697 - val_acc: 0.2963 - val_f1score: 0.2989 - val_recall_m: 0.2852 - val_precision_m: 0.3154
# Epoch 100/100
# 75/75 [==============================] - 87s 1s/step - loss: 0.1510 - acc: 0.9430 - f1score: 0.9430 - recall_m: 0.9430 - precision_m: 0.9430 - val_loss: 13.9072 - val_acc: 0.1222 - val_f1score: 0.1222 - val_recall_m: 0.1222 - val_precision_m: 0.1222

# %%
model.save('inceptionv3.h5')

# %%
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for recall
plt.plot(history.history['recall_m'])
plt.plot(history.history['val_recall_m'])
plt.title('model recall_m')
plt.ylabel('recall_m')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for precision
plt.plot(history.history['precision_m'])
plt.plot(history.history['val_precision_m'])
plt.title('model precision_m')
plt.ylabel('precision_m')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for f1score
plt.plot(history.history['f1score'])
plt.plot(history.history['val_f1score'])
plt.title('model f1score')
plt.ylabel('f1score')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'val_f1score', 'val_recall_m', 'val_precision_m', 'loss', 'acc', 'f1score', 'recall_m', 'precision_m'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-78cad4a18d9c> in <module>()
#       1 print(history.history.keys())
#       2 # summarize history for accuracy
# ----> 3 plt.plot(history.history['accuracy'])
#       4 plt.plot(history.history['val_accuracy'])
#       5 plt.title('model accuracy')
#
# KeyError: 'accuracy'
